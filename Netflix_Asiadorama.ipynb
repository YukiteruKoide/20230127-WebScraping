# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#ライブラリのインポート
from time import sleep
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# 変数urlにスクレイピングしたいURLを格納する
url = 'https://doga.hikakujoho.com/netflix/asiadrama/?page={}'

#変数outputに空のリストを作成する
output = []

#現在のurlを表示
print(url)
# Out:
# https://doga.hikakujoho.com/netflix/asiadrama/?page={}

# %%
#ループさせる
for i in range(1,3):
    
    #ループさせるために、target_urlの作成
    target_url = url.format(i)

    #dlistの長さを確認
    print("outputの大きさ:",len(output))
    
    #print()をしてtarget_urlを確かめる
    print(target_url)
 

    ##ここから実装が必要
    #ループさせるために、target_urlの作成

    #HTMLを取得
    res = requests.get(target_url)
    
    #スリープの実装
    sleep(2)

    #取得したHTMLを'BeautifulSoup'で解析
    soup = BeautifulSoup(res.text, 'html.parser')

    list_show_update = soup.find('ul',class_='list_show_update')

    span_tag = list_show_update.find_all('span',class_='fwb')

    span_strings = [x.string for x in span_tag]

    output.append(span_strings)
    
    print(output)
# Out:
# outputの大きさ: 0
# https://doga.hikakujoho.com/netflix/asiadrama/?page=1
# [['炎の壁', 'ふたりの私', 'ランド・オブ・スピリッツ: 若きシャーマンの物語', 'ミスマッチな関係!? シーズン2', 'バッドガイズ -悪には悪を-', '星明かりを見上げれば', '模範家族', 'マサバマサバ! シーズン2', 'ママ、やめて!', '愛は3日後に', 'マイ: 暗黒を束ねし者', '華燈初上 -夜を生きる女たち- パート2', '1989年の君へ', '華燈初上 -夜を生きる女たち-', '酸いも。甘いも。 シーズン3', '悲しみより、もっと悲しい物語 The Series', 'リメンバー・ユー', '愛が必要 I Need Romance', 'フィール・ライク・イシュク', '理性的な人生', "Let's Eat 〜ゴハン行こうよ〜 Let's Eat", 'ワーキングママ シーズン5', '転校生ナノ シーズン2', "恋する幽霊バスターズ Let's Fight Ghost", 'アブラ・ファヒータ： ディーバの反撃', 'ボンベイ・ベイガム -私たちのサバイバル-', '情熱のアンソロジー', '未来モール', '謗法〜運命を変える方法〜', '不徳のアンソロジー', '返校', 'ミスマッチな関係!?', '理想の花婿 リミテッドシリーズ', '天巡者', 'ビー・マイ・メイビー', 'マサバマサバ!', 'ダークデザイア', '青春はヘビーパンチ', '落ちこぼれ組', 'Whispers/ウィスパーズ', '明蘭 〜才媛の春〜', 'ベタール', 'スリープレス・ソサエティ: 2つの枕と失われた魂', '次の被害者', 'ハスムーク', 'GHOUL/グール(2018年)', '旦那様はドナー シーズン2', 'SHE -本当の私-', 'タージ・マハル、1989', '働く女子流ワタシ探し', '霊剣山', '彼岸の花嫁', 'スリープレス・ソサエティ: 不眠症の女', '絶代双驕 マーベラス・ツインズ', '恋は不意打ち', '恋するマフィア娘', '料理が冷めないうちに', '流星花園(2018年・韓国)', '鳳凰の飛翔', '片思い 〜秘密の恋心〜', '反逆の季節', '転校生ナノ', '昼と夜', '旦那様はドナー シーズン1', '待って、私の青春', '双城故事: 彼女たちの二都物語', '千の壁を超えて', '先生、本当の恋って?', '積み木でできた家', '正義の天使', '初恋という名の小さな宝物', '子供はあなたの所有物じゃない', '罪夢者', '最後はキミを好きになる!', '香港ウェスト・サイド・ストーリー', '鋼の刑事', '幻城 Ice
ォリアー 〜愛しの戦士さま〜', 'ボイス -緊急通報191-', 'バンコク・ラブストーリー: プリーズ', 'バンコク・ラブストーリー: イノセンス', 'バンコク・ラブストーリー: アフェクション', 'バンコク・バディーズ!', 'トンネル: 記憶のパーツ', 'テニスの王子様 〜奮闘せよ、少年!〜', 'シンガポール・ソーシャル', 'しあわせのモーメント シーズン3', 'しあわせのモーメント シーズン2', 'しあわせのモーメント シーズン1', 'グリーン・ドア -傷ついた魂の集う場所-', 'キャンディー・オンライン'], ['お花畑から来た少年', 'エターナル・ラブ 三生三世', 'CHOSEN 終わりなき殺人ゲーム シーズン2', 'CHOSEN 終わりなき殺人ゲーム シーズン1', '三国志 Secret of Three Kingdoms', '花と将軍〜Oh My General〜', '恋のゴールドメダル〜僕が恋したキム・ボクジュ〜', '秋のコンチェルト', '元カレは天才詐欺師 〜38師機動隊〜', '王子變青蛙 カエルになった王子様', 'ハートに命中100%', 'じれったいロマンス', 'ドクターズ', 'シンデレラはオンライン中!']]

# %%
output[:2]
# Out:
# [['炎の壁',
#   'ふたりの私',
#   'ランド・オブ・スピリッツ: 若きシャーマンの物語',
#   'ミスマッチな関係!? シーズン2',
#   'バッドガイズ -悪には悪を-',
#   '星明かりを見上げれば',
#   '模範家族',
#   'マサバマサバ! シーズン2',
#   'ママ、やめて!',
#   '愛は3日後に',
#   'マイ: 暗黒を束ねし者',
#   '華燈初上 -夜を生きる女たち- パート2',
#   '1989年の君へ',
#   '華燈初上 -夜を生きる女たち-',
#   '酸いも。甘いも。 シーズン3',
#   '悲しみより、もっと悲しい物語 The Series',
#   'リメンバー・ユー',
#   '愛が必要 I Need Romance',
#   'フィール・ライク・イシュク',
#   '理性的な人生',
#   "Let's Eat 〜ゴハン行こうよ〜 Let's Eat",
#   'ワーキングママ シーズン5',
#   '転校生ナノ シーズン2',
#   "恋する幽霊バスターズ Let's Fight Ghost",
#   'アブラ・ファヒータ： ディーバの反撃',
#   'ボンベイ・ベイガム -私たちのサバイバル-',
#   '情熱のアンソロジー',
#   '未来モール',
#   '謗法〜運命を変える方法〜',
#   '不徳のアンソロジー',
#   '返校',
#   'ミスマッチな関係!?',
#   '理想の花婿 リミテッドシリーズ',
#   '天巡者',
#   'ビー・マイ・メイビー',
#   'マサバマサバ!',
#   'ダークデザイア',
#   '青春はヘビーパンチ',
#   '落ちこぼれ組',
#   'Whispers/ウィスパーズ',
#   '明蘭 〜才媛の春〜',
#   'ベタール',
#   'スリープレス・ソサエティ: 2つの枕と失われた魂',
#   '次の被害者',
#   'ハスムーク',
#   'GHOUL/グール(2018年)',
#   '旦那様はドナー シーズン2',
#   'SHE -本当の私-',
#   'タージ・マハル、1989',
#   '働く女子流ワタシ探し',
#   '霊剣山',
#   '彼岸の花嫁',
#   'スリープレス・ソサエティ: 不眠症の女',
#   '絶代双驕 マーベラス・ツインズ',
#   '恋は不意打ち',
#   '恋するマフィア娘',
#   '料理が冷めないうちに',
#   '流星花園(2018年・韓国)',
#   '鳳凰の飛翔',
#   '片思い 〜秘密の恋心〜',
#   '反逆の季節',
#   '転校生ナノ',
#   '昼と夜',
#   '旦那様はドナー シーズン1',
#   '待って、私の青春',
#   '双城故事: 彼女たちの二都物語',
#   '千の壁を超えて',
#   '先生、本当の恋って?',
#   '積み木でできた家',
#   '正義の天使',
#   '初恋という名の小さな宝物',
#   '子供はあなたの所有物じゃない',
#   '罪夢者',
#   '最後はキミを好きになる!',
#   '香港ウェスト・サイド・ストーリー',
#   '鋼の刑事',
#   '幻城 Ice Fantasy',
#   '兄に付ける薬はない!(実写版)',
#   '金枝玉葉 〜新たな王妃となりし者〜',
#   '恐怖の劇場',
#   '王子様(2018年)',
#   '一千回のおやすみを',
#   '暗闇は目を閉じて',
#   'もっともステキなコト',
#   'ミス・シェフ',
#   'マスターオブスキル 全職高手',
#   'マイ・ディア・ウォリアー 〜愛しの戦士さま〜',
#   'ボイス -緊急通報191-',
#   'バンコク・ラブストーリー: プリーズ',
#   'バンコク・ラブストーリー: イノセンス',
#   'バンコク・ラブストーリー: アフェクション',
#   'バンコク・バディーズ!',
#   'トンネル: 記憶のパーツ',
#   'テニスの王子様 〜奮闘せよ、少年!〜',
#   'シンガポール・ソーシャル',
#   'しあわせのモーメント シーズン3',
#   'しあわせのモーメント シーズン2',
#   'しあわせのモーメント シーズン1',
#   'グリーン・ドア -傷ついた魂の集う場所-',
#   'キャンディー・オンライン'],
#  ['お花畑から来た少年',
#   'エターナル・ラブ 三生三世',
#   'CHOSEN 終わりなき殺人ゲーム シーズン2',
#   'CHOSEN 終わりなき殺人ゲーム シーズン1',
#   '三国志 Secret of Three Kingdoms',
#   '花と将軍〜Oh My General〜',
#   '恋のゴールドメダル〜僕が恋したキム・ボクジュ〜',
#   '秋のコンチェルト',
#   '元カレは天才詐欺師 〜38師機動隊〜',
#   '王子變青蛙 カエルになった王子様',
#   'ハートに命中100%',
#   'じれったいロマンス',
#   'ドクターズ',
#   'シンデレラはオンライン中!']]

# %%
##データフレームを作成する
df=pd.DataFrame(output)

#中身の確認
df.head()
# Out:
#           0              1                         2   \
# 0        炎の壁          ふたりの私  ランド・オブ・スピリッツ: 若きシャーマンの物語
# 1  お花畑から来た少年  エターナル・ラブ 三生三世   CHOSEN 終わりなき殺人ゲーム シーズン2
#
#                         3                             4                    5   \
# 0         ミスマッチな関係!? シーズン2                バッドガイズ -悪には悪を-           星明かりを見上げれば
# 1  CHOSEN 終わりなき殺人ゲーム シーズン1  三国志 Secret of Three Kingdoms  花と将軍〜Oh My General〜
#
#                         6              7                   8   \
# 0                     模範家族  マサバマサバ! シーズン2             ママ、やめて!
# 1  恋のゴールドメダル〜僕が恋したキム・ボクジュ〜       秋のコンチェルト  元カレは天才詐欺師 〜38師機動隊〜
#
#                  9   ...                     90           91            92  \
# 0            愛は3日後に  ...  バンコク・ラブストーリー: アフェクション  バンコク・バディーズ!  トンネル: 記憶のパーツ
# 1  王子變青蛙 カエルになった王子様  ...                   None         None          None
#
#                    93            94                95                96  \
# 0  テニスの王子様 〜奮闘せよ、少年!〜  シンガポール・ソーシャル  しあわせのモーメント シーズン3  しあわせのモーメント シーズン2
# 1                None          None              None              None
#
#                  97                    98            99
# 0  しあわせのモーメント シーズン1  グリーン・ドア -傷ついた魂の集う場所-  キャンディー・オンライン
# 1              None                  None          None
#
# [2 rows x 100 columns]

# %%
##to_csvを使用してcsv出力する
df.to_csv('NETFLIX_アジアドラマ.csv' ,encoding = 'utf-8-sig')
