# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (2022.9.24)
# Note: you may need to restart the kernel to use updated packages.

# %%
#ライブラリのインポート
from time import sleep
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# 変数urlにスクレイピングしたいURLを格納する
url = 'https://doga.hikakujoho.com/netflix/all-lineup/?page={}'

#変数outputに空のリストを作成する
output = []

#現在のurlを表示
#print(url)

# %%
#ループさせる
for i in range(1,74):
    
    #ループさせるために、target_urlの作成
    target_url = url.format(i)

    #dlistの長さを確認
    print("outputの大きさ:",len(output))
    
    #print()をしてtarget_urlを確かめる
    print(target_url)
 

    ##ここから実装が必要
    #ループさせるために、target_urlの作成

    #HTMLを取得
    res = requests.get(target_url)
    
    #スリープの実装
    sleep(2)

    #取得したHTMLを'BeautifulSoup'で解析
    soup = BeautifulSoup(res.text, 'html.parser')

    list_show_update = soup.find('ul',class_='list_show_update')

    span_tag = list_show_update.find_all('span',class_='fwb')

    span_strings = [x.string for x in span_tag]

    output.append(span_strings)
    
    #print(output)
# Out:
# outputの大きさ: 0
# https://doga.hikakujoho.com/netflix/all-lineup/?page=1
# outputの大きさ: 1
# https://doga.hikakujoho.com/netflix/all-lineup/?page=2
# outputの大きさ: 2
# https://doga.hikakujoho.com/netflix/all-lineup/?page=3
# outputの大きさ: 3
# https://doga.hikakujoho.com/netflix/all-lineup/?page=4
# outputの大きさ: 4
# https://doga.hikakujoho.com/netflix/all-lineup/?page=5
# outputの大きさ: 5
# https://doga.hikakujoho.com/netflix/all-lineup/?page=6
# outputの大きさ: 6
# https://doga.hikakujoho.com/netflix/all-lineup/?page=7
# outputの大きさ: 7
# https://doga.hikakujoho.com/netflix/all-lineup/?page=8
# outputの大きさ: 8
# https://doga.hikakujoho.com/netflix/all-lineup/?page=9
# outputの大きさ: 9
# https://doga.hikakujoho.com/netflix/all-lineup/?page=10
# outputの大きさ: 10
# https://doga.hikakujoho.com/netflix/all-lineup/?page=11
# outputの大きさ: 11
# https://doga.hikakujoho.com/netflix/all-lineup/?page=12
# outputの大きさ: 12
# https://doga.hikakujoho.com/netflix/all-lineup/?page=13
# outputの大きさ: 13
# https://doga.hikakujoho.com/netflix/all-lineup/?page=14
# outputの大きさ: 14
# https://doga.hikakujoho.com/netflix/all-lineup/?page=15
# outputの大きさ: 15
# https://doga.hikakujoho.com/netflix/all-lineup/?page=16
# outputの大きさ: 16
# https://doga.hikakujoho.com/netflix/all-lineup/?page=17
# outputの大きさ: 17
# https://doga.hikakujoho.com/netflix/all-lineup/?page=18
# outputの大きさ: 18
# https://doga.hikakujoho.com/netflix/all-lineup/?page=19
# outputの大きさ: 19
# https://doga.hikakujoho.com/netflix/all-lineup/?page=20
# outputの大きさ: 20
# https://doga.hikakujoho.com/netflix/all-lineup/?page=21
# outputの大きさ: 21
# https://doga.hikakujoho.com/netflix/all-lineup/?page=22
# outputの大きさ: 22
# https://doga.hikakujoho.com/netflix/all-lineup/?page=23
# outputの大きさ: 23
# https://doga.hikakujoho.com/netflix/all-lineup/?page=24
# outputの大きさ: 24
# https://doga.hikakujoho.com/netflix/all-lineup/?page=25
# outputの大きさ: 25
# https://doga.hikakujoho.com/netflix/all-lineup/?page=26
# outputの大きさ: 26
# https://doga.hikakujoho.com/netflix/all-lineup/?page=27
# outputの大きさ: 27
# https://doga.hikakujoho.com/netflix/all-lineup/?page=28
# outputの大きさ: 28
# https://doga.hikakujoho.com/netflix/all-lineup/?page=29
# outputの大きさ: 29
# https://doga.hikakujoho.com/netflix/all-lineup/?page=30
# outputの大きさ: 30
# https://doga.hikakujoho.com/netflix/all-lineup/?page=31
# outputの大きさ: 31
# https://doga.hikakujoho.com/netflix/all-lineup/?page=32
# outputの大きさ: 32
# https://doga.hikakujoho.com/netflix/all-lineup/?page=33
# outputの大きさ: 33
# https://doga.hikakujoho.com/netflix/all-lineup/?page=34
# outputの大きさ: 34
# https://doga.hikakujoho.com/netflix/all-lineup/?page=35
# outputの大きさ: 35
# https://doga.hikakujoho.com/netflix/all-lineup/?page=36
# outputの大きさ: 36
# https://doga.hikakujoho.com/netflix/all-lineup/?page=37
# outputの大きさ: 37
# https://doga.hikakujoho.com/netflix/all-lineup/?page=38
# outputの大きさ: 38
# https://doga.hikakujoho.com/netflix/all-lineup/?page=39
# outputの大きさ: 39
# https://doga.hikakujoho.com/netflix/all-lineup/?page=40
# outputの大きさ: 40
# https://doga.hikakujoho.com/netflix/all-lineup/?page=41
# outputの大きさ: 41
# https://doga.hikakujoho.com/netflix/all-lineup/?page=42
# outputの大きさ: 42
# https://doga.hikakujoho.com/netflix/all-lineup/?page=43
# outputの大きさ: 43
# https://doga.hikakujoho.com/netflix/all-lineup/?page=44
# outputの大きさ: 44
# https://doga.hikakujoho.com/netflix/all-lineup/?page=45
# outputの大きさ: 45
# https://doga.hikakujoho.com/netflix/all-lineup/?page=46
# outputの大きさ: 46
# https://doga.hikakujoho.com/netflix/all-lineup/?page=47
# outputの大きさ: 47
# https://doga.hikakujoho.com/netflix/all-lineup/?page=48
# outputの大きさ: 48
# https://doga.hikakujoho.com/netflix/all-lineup/?page=49
# outputの大きさ: 49
# https://doga.hikakujoho.com/netflix/all-lineup/?page=50
# outputの大きさ: 50
# https://doga.hikakujoho.com/netflix/all-lineup/?page=51
# outputの大きさ: 51
# https://doga.hikakujoho.com/netflix/all-lineup/?page=52
# outputの大きさ: 52
# https://doga.hikakujoho.com/netflix/all-lineup/?page=53
# outputの大きさ: 53
# https://doga.hikakujoho.com/netflix/all-lineup/?page=54
# outputの大きさ: 54
# https://doga.hikakujoho.com/netflix/all-lineup/?page=55
# outputの大きさ: 55
# https://doga.hikakujoho.com/netflix/all-lineup/?page=56
# outputの大きさ: 56
# https://doga.hikakujoho.com/netflix/all-lineup/?page=57
# outputの大きさ: 57
# https://doga.hikakujoho.com/netflix/all-lineup/?page=58
# outputの大きさ: 58
# https://doga.hikakujoho.com/netflix/all-lineup/?page=59
# outputの大きさ: 59
# https://doga.hikakujoho.com/netflix/all-lineup/?page=60
# outputの大きさ: 60
# https://doga.hikakujoho.com/netflix/all-lineup/?page=61
# outputの大きさ: 61
# https://doga.hikakujoho.com/netflix/all-lineup/?page=62
# outputの大きさ: 62
# https://doga.hikakujoho.com/netflix/all-lineup/?page=63
# outputの大きさ: 63
# https://doga.hikakujoho.com/netflix/all-lineup/?page=64
# outputの大きさ: 64
# https://doga.hikakujoho.com/netflix/all-lineup/?page=65
# outputの大きさ: 65
# https://doga.hikakujoho.com/netflix/all-lineup/?page=66
# outputの大きさ: 66
# https://doga.hikakujoho.com/netflix/all-lineup/?page=67
# outputの大きさ: 67
# https://doga.hikakujoho.com/netflix/all-lineup/?page=68
# outputの大きさ: 68
# https://doga.hikakujoho.com/netflix/all-lineup/?page=69
# outputの大きさ: 69
# https://doga.hikakujoho.com/netflix/all-lineup/?page=70
# outputの大きさ: 70
# https://doga.hikakujoho.com/netflix/all-lineup/?page=71
# outputの大きさ: 71
# https://doga.hikakujoho.com/netflix/all-lineup/?page=72
# outputの大きさ: 72
# https://doga.hikakujoho.com/netflix/all-lineup/?page=73

# %%
#output[:2]

# %%
##データフレームを作成する
df=pd.DataFrame(output)

#中身の確認
#df.head()

# %%
##to_csvを使用してcsv出力する
df.to_csv('NETFLIX_全ジャンル.csv' ,encoding = 'utf-8-sig')
