# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
#ライブラリのインポート
from time import sleep
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# 変数urlにスクレイピングしたいURLを格納する
url = 'https://doga.hikakujoho.com/netflix/koreandrama/?page={}'

#変数outputに空のリストを作成する
output = []

#現在のurlを表示
print(url)
# Out:
# https://doga.hikakujoho.com/netflix/koreandrama/?page={}

# %%
#ループさせる
for i in range(1,4):
    
    #ループさせるために、target_urlの作成
    target_url = url.format(i)

    #dlistの長さを確認
    print("outputの大きさ:",len(output))
    
    #print()をしてtarget_urlを確かめる
    print(target_url)
 

    ##ここから実装が必要
    #ループさせるために、target_urlの作成

    #HTMLを取得
    res = requests.get(target_url)
    
    #スリープの実装
    sleep(2)

    #取得したHTMLを'BeautifulSoup'で解析
    soup = BeautifulSoup(res.text, 'html.parser')

    list_show_update = soup.find('ul',class_='list_show_update')

    span_tag = list_show_update.find_all('span',class_='fwb')

    span_strings = [x.string for x in span_tag]

    output.append(span_strings)
    
    print(output)
# Out:
# outputの大きさ: 0
# https://doga.hikakujoho.com/netflix/koreandrama/?page=1
# [['イルタ・スキャンダル 〜恋は特訓コースで〜', 'ザ・グローリー 〜輝かしき復讐〜', 'ザ・ファビュラス', '愛と、利と', '車輪', '還魂 パート2', 'サムバディ', 'エージェントなお仕事', 'シュルプ', 'TAKE ONE 〜マイ・ラスト・ソング〜', 'ミッシング 〜彼らがいた〜 Missing: The Other Side', 'グリッチ -青い閃光の記憶-', 'ナルコの神', '田舎街ダイアリーズ', 'シスターズ(2022年)', '花様年華 -人生が花になる瞬間-', '再婚ゲーム', 'オー・マイ・ベイビー', '美男堂の事件手帳', 'ペーパー・ハウス・コリア: 統一通貨を奪え', '還魂 パート1', '医師 ヨハン シーズン1', '結婚白書 シーズン1', 'アンナラスマナラ -魔法の旋律-', '私の解放日誌', '私たちのブルース', 'グリーン・マザーズ・クラブ', '明日(韓国ドラマ)', 'ブラームスは好きですか?', '悪の花', '社内お見合い', '未成年裁判', '結婚作詞 離婚作曲 シーズン3', '二十五、二十一', '気象庁の人々: 社内恋愛は予測不能？！', '39歳', '今、私たちの学校は...', '静かなる海', '不可殺 -永遠を生きる者-', '腹ペコとモジャモジャ', '地獄が呼んでいる', '真心が届く 〜僕とスターのオフィス・ラブ！？〜 Touch Your Heart', '調査官ク・ギョンイ', '浪漫ドクター キム・サブ2', 'マイネーム: 偽りと復讐', 'あなたに似た人', '恋慕', 'ペク・ジョンウォンの呑んで、食べて、語って', 'イカゲーム', '夫婦の世界', '海街チャチャチャ', 'D.P. -脱走兵追跡官-', 'ボーイフレンド Encounter', '冷麺賛歌 〜韓国のおいしいを探訪〜', '天気がよければ会いにゆきます', '君は私の春', 'わかっていても', 'ホント無理だから', '賢い医師生活 シーズン2', '結婚作詞 離婚作曲 シーズン2', 'バッドガイズ -悪の都市-', 'ラケット少年団', '
キレイだった(韓国ドラマ)', '花郎<ファラン>', 'また!?オ・ヘヨン 〜僕が愛した未来〜', 'ピノキオ(2014年・韓流ドラマ)', 'シンデレラと4人の騎士<ナイト>', 'ドクター異邦人', 'エンジェルアイズ', '花より男子〜Boys Over Flowers', 'キルミー・ヒールミー', 'ミセン -未生-', '運命のように君を愛してる', '奇皇后 ふたつの愛 涙の誓い'], ['宮 -クン- 〜Love in Palace〜', '美男ですね(韓国)', 'ドリームハイ2', 'ドリームハイ', 'シンイ-信義-', 'パスタ〜恋が出来るまで〜', '君の声が聞こえる', '相続者たち', 'コーヒープリンス1号店', 'イタズラなKiss〜Playful Kiss', 'トキメキ☆成均館スキャンダル', '太陽を抱く月', 'シークレット・ガーデン']]

# %%
output[:2]
# Out:
# [['イルタ・スキャンダル 〜恋は特訓コースで〜',
#   'ザ・グローリー 〜輝かしき復讐〜',
#   'ザ・ファビュラス',
#   '愛と、利と',
#   '車輪',
#   '還魂 パート2',
#   'サムバディ',
#   'エージェントなお仕事',
#   'シュルプ',
#   'TAKE ONE 〜マイ・ラスト・ソング〜',
#   'ミッシング 〜彼らがいた〜 Missing: The Other Side',
#   'グリッチ -青い閃光の記憶-',
#   'ナルコの神',
#   '田舎街ダイアリーズ',
#   'シスターズ(2022年)',
#   '花様年華 -人生が花になる瞬間-',
#   '再婚ゲーム',
#   'オー・マイ・ベイビー',
#   '美男堂の事件手帳',
#   'ペーパー・ハウス・コリア: 統一通貨を奪え',
#   '還魂 パート1',
#   '医師 ヨハン シーズン1',
#   '結婚白書 シーズン1',
#   'アンナラスマナラ -魔法の旋律-',
#   '私の解放日誌',
#   '私たちのブルース',
#   'グリーン・マザーズ・クラブ',
#   '明日(韓国ドラマ)',
#   'ブラームスは好きですか?',
#   '悪の花',
#   '社内お見合い',
#   '未成年裁判',
#   '結婚作詞 離婚作曲 シーズン3',
#   '二十五、二十一',
#   '気象庁の人々: 社内恋愛は予測不能？！',
#   '39歳',
#   '今、私たちの学校は...',
#   '静かなる海',
#   '不可殺 -永遠を生きる者-',
#   '腹ペコとモジャモジャ',
#   '地獄が呼んでいる',
#   '真心が届く 〜僕とスターのオフィス・ラブ！？〜 Touch Your Heart',
#   '調査官ク・ギョンイ',
#   '浪漫ドクター キム・サブ2',
#   'マイネーム: 偽りと復讐',
#   'あなたに似た人',
#   '恋慕',
#   'ペク・ジョンウォンの呑んで、食べて、語って',
#   'イカゲーム',
#   '夫婦の世界',
#   '海街チャチャチャ',
#   'D.P. -脱走兵追跡官-',
#   'ボーイフレンド Encounter',
#   '冷麺賛歌 〜韓国のおいしいを探訪〜',
#   '天気がよければ会いにゆきます',
#   '君は私の春',
#   'わかっていても',
#   'ホント無理だから',
#   '賢い医師生活 シーズン2',
#   '結婚作詞 離婚作曲 シーズン2',
#   'バッドガイズ -悪の都市-',
#   'ラケット少年団',
#   'このエリアのクレイジーX',
#   'ムーブ・トゥ・ヘブン: 私は遺品整理士です',
#   '恋愛革命',
#   'Mine',
#   'VIP-迷路の始まり-',
#   'ブラックドッグ〜新米教師コ・ハヌル〜',
#   'ロースクール',
#   'ナビレラ −それでも蝶は舞う−',
#   '恋するアプリ Love Alarm シーズン2',
#   'ストーブリーグ',
#   'ヴィンチェンツォ',
#   'こんにちは？ 私だよ！',
#   'シーシュポス： The Myth',
#   '絶対彼氏。',
#   '悪霊狩猟団: カウンターズ',
#   '結婚作詞 離婚作曲',
#   '美しかった私たちへ',
#   '都会の男女の恋愛法',
#   'Sweet Home -俺と世界の絶望-',
#   'それでも僕らは走り続ける',
#   'ドドソソララソ',
#   'プライバシー戦争',
#   '偶然見つけたハル',
#   '恋愛ワードを入力してください〜Search WWW〜',
#   '初対面だけど愛してます',
#   'スタートアップ: 夢の扉',
#   '秘密の森 シーズン2',
#   '十八の瞬間',
#   '保健教師アン・ウニョン',
#   '青春の記録',
#   '私たち、恋してたのかな?',
#   'まぶしくて-私たちの輝く時間-',
#   '彼女の私生活',
#   'サンガプ屋台',
#   'サイコだけど大丈夫',
#   '賢い医師生活',
#   '皇后の品格',
#   '私の国'],
#  ['君のせいで何もできない!',
#   'RUGAL/ルーガル',
#   '人間レッスン',
#   'ハイバイ、ママ!',
#   '100日の郎君様',
#   '適齢期惑々ロマンス〜お父さんが変!?〜',
#   'ハイエナ -弁護士たちの生存ゲーム-',
#   'ザ・キング: 永遠の君主',
#   '不夜城(2016年・韓国)',
#   'アビス(2019年)',
#   '愛の不時着',
#   '愛しのホロ',
#   'チョコレート: 忘れかけてた幸せの味',
#   'キングダム シーズン2(2020年・韓国)',
#   '梨泰院クラス',
#   'ボイス3 -112の奇跡-',
#   'ジャスティス -検法男女- シーズン2',
#   '憑依 〜殺人鬼を追え〜',
#   '恋するアプリ Love Alarm シーズン1',
#   '補佐官 シーズン2',
#   '補佐官 シーズン1',
#   '非正規職アイドル',
#   '椿の花咲く頃',
#   '青春時代 シーズン2',
#   '新米史官ク・ヘリョン',
#   '初恋は初めてなので シーズン2',
#   '初恋は初めてなので シーズン1',
#   '死の賛美',
#   'ロマンスは別冊付録',
#   'ユ・ヨルの音楽アルバム',
#   'みんなの嘘',
#   'ミスター・サンシャイン',
#   'マイ・ランウェイ',
#   'マイ・オンリー・ラブソング',
#   'サバイバー: 60日間の大統領',
#   'サウンド・オブ・ハート: リブート シーズン2',
#   'サウンド・オブ・ハート: リブート シーズン1',
#   'サウンド・オブ・ハート',
#   'コリアン・オデッセイ: 花遊記',
#   'こころに陽があたるまで',
#   'キングダム シーズン1(2020年・韓国)',
#   'ある春の夜に',
#   'アルハンブラ宮殿の思い出',
#   'アスダル年代記',
#   'YG未来戦略室',
#   'Vagabond/バガボンド',
#   'とにかくアツく掃除しろ!〜恋した彼は潔癖王子!?〜',
#   '無法弁護士〜最高のパートナー',
#   '第3の魅力〜終わらない恋の始まり〜',
#   '恋する十二夜〜キミとボクの8年間〜',
#   'ピョン・ヒョクの恋',
#   '刑務所のルールブック',
#   '客ーザ・ゲストー',
#   'ジャスティス -検法男女- シーズン1',
#   '恋のトリセツ-フンナムとジョンウムの恋愛日誌-',
#   'マイ・ディア・ミスター〜私のおじさん〜',
#   '止めたい時間:アバウトタイム',
#   'ボイス2 -112の奇跡-',
#   'ウラチャチャ My Love',
#   '知ってるワイフ (韓国ドラマ)',
#   'ロマンスは命がけ!?',
#   'キム秘書はいったい、なぜ?',
#   '華麗なるスパイス',
#   '私のIDはカンナム美人',
#   'ブラック〜恋する死神〜',
#   'ここに来て抱きしめて',
#   'この恋は初めてだから',
#   '偉大な誘惑者',
#   'ライブ〜君こそが生きる理由〜',
#   'よくおごってくれる綺麗なお姉さん',
#   '法廷プリンス - イ判サ判 -',
#   'ただ愛する仲',
#   '黄金の私の人生',
#   '秘密の森 シーズン1',
#   '自己発光オフィス〜拝啓運命の女神さま!〜',
#   'ハベクの新婦',
#   '医心伝心〜脈あり!恋あり?〜',
#   '内省的なボス',
#   '品位のある彼女',
#   'トッケビ〜君がくれた愛しい日々〜',
#   '猟奇的な彼女(韓国・ドラマ)',
#   '被告人',
#   'あやしいパートナー 〜Destiny Lovers〜',
#   '野獣の美女コンシム',
#   '青い海の伝説',
#   '1%の奇跡 〜運命を変える恋〜',
#   '恋のスケッチ〜応答せよ1988〜',
#   'モンスター 〜その愛と復讐〜',
#   '彼女はキレイだった(韓国ドラマ)',
#   '花郎<ファラン>',
#   'また!?オ・ヘヨン 〜僕が愛した未来〜',
#   'ピノキオ(2014年・韓流ドラマ)',
#   'シンデレラと4人の騎士<ナイト>',
#   'ドクター異邦人',
#   'エンジェルアイズ',
#   '花より男子〜Boys Over Flowers',
#   'キルミー・ヒールミー',
#   'ミセン -未生-',
#   '運命のように君を愛してる',
#   '奇皇后 ふたつの愛 涙の誓い']]

# %%
##データフレームを作成する
df=pd.DataFrame(output)

#中身の確認
df.head()
# Out:
#                         0                 1         2         3         4   \
# 0    イルタ・スキャンダル 〜恋は特訓コースで〜  ザ・グローリー 〜輝かしき復讐〜  ザ・ファビュラス     愛と、利と        車輪
# 1             君のせいで何もできない!        RUGAL/ルーガル    人間レッスン  ハイバイ、ママ!  100日の郎君様
# 2  宮 -クン- 〜Love in Palace〜         美男ですね(韓国)   ドリームハイ2    ドリームハイ   シンイ-信義-
#
#                     5                   6             7              8   \
# 0              還魂 パート2               サムバディ    エージェントなお仕事           シュルプ
# 1  適齢期惑々ロマンス〜お父さんが変!?〜  ハイエナ -弁護士たちの生存ゲーム-  ザ・キング: 永遠の君主  不夜城(2016年・韓国)
# 2         パスタ〜恋が出来るまで〜            君の声が聞こえる         相続者たち    コーヒープリンス1号店
#
#                        9   ...                   90                 91  \
# 0   TAKE ONE 〜マイ・ラスト・ソング〜  ...          保健教師アン・ウニョン              青春の記録
# 1              アビス(2019年)  ...  また!?オ・ヘヨン 〜僕が愛した未来〜  ピノキオ(2014年・韓流ドラマ)
# 2  イタズラなKiss〜Playful Kiss  ...                 None               None
#
#                  92               93        94                       95  \
# 0      私たち、恋してたのかな?  まぶしくて-私たちの輝く時間-    彼女の私生活                   サンガプ屋台
# 1  シンデレラと4人の騎士<ナイト>          ドクター異邦人  エンジェルアイズ  花より男子〜Boys Over Flowers
# 2              None             None      None                     None
#
#            96        97            98              99
# 0   サイコだけど大丈夫    賢い医師生活         皇后の品格             私の国
# 1  キルミー・ヒールミー  ミセン -未生-  運命のように君を愛してる  奇皇后 ふたつの愛 涙の誓い
# 2        None      None          None            None
#
# [3 rows x 100 columns]

# %%
##to_csvを使用してcsv出力する
df.to_csv('NETFLIX_韓流ドラマ.csv' ,encoding = 'utf-8-sig')
