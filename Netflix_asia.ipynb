# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/koideyukiteru/opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
#ライブラリのインポート
from time import sleep
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# 変数urlにスクレイピングしたいURLを格納する
url = 'https://doga.hikakujoho.com/netflix/asiamovie/?page={}'

#変数outputに空のリストを作成する
output = []

#現在のurlを表示
print(url)
# Out:
# https://doga.hikakujoho.com/netflix/asiamovie/?page={}

# %%
#ループさせる
for i in range(1,5):
    
    #ループさせるために、target_urlの作成
    target_url = url.format(i)

    #dlistの長さを確認
    print("outputの大きさ:",len(output))
    
    #print()をしてtarget_urlを確かめる
    print(target_url)
 

    ##ここから実装が必要
    #ループさせるために、target_urlの作成

    #HTMLを取得
    res = requests.get(target_url)
    
    #スリープの実装
    sleep(2)

    #取得したHTMLを'BeautifulSoup'で解析
    soup = BeautifulSoup(res.text, 'html.parser')

    list_show_update = soup.find('ul',class_='list_show_update')

    span_tag = list_show_update.find_all('span',class_='fwb')

    span_strings = [x.string for x in span_tag]

    output.append(span_strings)
    
    print(output)
# Out:
# outputの大きさ: 0
# https://doga.hikakujoho.com/netflix/asiamovie/?page=1
# [['JUNG_E/ジョンイ', '罪の後', 'ミッション・マジュヌ', 'アルハラート+', '未来戦記', 'マツの木の家族2', '20世紀のキミ', '奇跡の13人: 僕らのタイ洞窟生還記', 'ソウル・バイブス', 'ダーリンズ', '一家の主', 'カーター', '呪詛', '素晴らしき眺め', 'サイバー地獄: n番部屋 ネット犯罪を暴く', '夜叉 -容赦なき工作戦-', 'セレブファイブ 〜大舞台への道〜', 'アメリカン・ガール', 'パイレーツ: 失われた王家の秘宝', '瀑布', '真・三國無双', 'ライトニング・ムラリ', 'アリサカ', '真実の穴', '白蛇2: 青蛇興起', 'Look for a Star -星を探して-', 'ビューティフル・ライフ -もう二度と離さない-', '独身の行方', 'SDU 飛虎出征', 'ダマカ: テロ独占生中継', 'チートゲーム', 'わたしたちの愛の距離', 'ゼロからのヒーロー', 'Pomegranates and Myrrh', 'この夏の先には', 'つかみ損ねた恋に: ディレクターズカット', '君が最後の初恋', 'キングダム: アシンの物語', 'スカした彼はサイキック', '美に魅せられて', '第8日の夜', '返校 言葉が消えた日', '甘酸っぱい', '野球少女', '角頭−彷徨人', '最後の願い', 'マイルストーン', 'スーパー・ミー', '密航者', 'ただならない物語', 'The Soul: 繋がれる魂', '楽園の夜', 'ギス＆アン', '愛を探して', 'ワーニング その映画を観るな', 'おかしな子', '陰陽師： 二つの世界', '杏林医院', 'こどもなんてお断り！', 'ヤギを追跡せよ', 'サヤン・ディサヤン： 愛しき人よ', '私たちの歌： 新謡が紡いだ時代', '881 歌え！ パパイヤ', 'ホームラン', '悩める青春のススメ', '詩人の恋', '日々は、うたかたに', 'すばらしき大世界', '同級生マイナス', '世宗大王 星を追う者たち', 'ナマステ・ワハラ ~トラブルよ、こんにちは~', '弱くて強い女たち', 'スペース・スウィーパーズ', '陰陽師 とこしえの夢', 'ナタ転生', "Pinkfong & Baby Shark's Space Adventure", 'なんと父よ!', 'トリバンガ 〜踊れ艶やかに〜', 'Wish you 〜僕の心の中、君のメロディー(映画)', 'デリー・ゲリー', 'アジズのジレンマ', '縄の呪い2', 'チャ・インピョはどこへ消えたのか?', '薬の神じゃない!', 'AKvsAK', '君の心に刻んだ名前', '希望の光', '母の面影が語ること', 'ザ・コール', 'アルター・ミー: 心に耳を傾けて', 'LUDO 〜4つの物語〜', "Girl's Revenge", '漆黒の井戸の底から', '誰も眠らない森', 'ニャンてこと!', 'ルーナのために', 'KCIA 南山の部長たち', 'ハクション!', 'ギニーとサニーの結婚', 'この子をよろしく 〜突然!? 育児トライアル〜']]
# outputの大きさ: 1
# https://doga.hikakujoho.com/netflix/asiamovie/?page=2
# [['JUNG_E/ジョンイ', '罪の後', 'ミッション・マジュヌ', 'アルハラート+', '未来戦記', 'マツの木の家族2', '20世紀のキミ', '奇跡の13人: 僕らのタイ洞窟生還記', 'ソウル・バイブス', 'ダーリンズ', '一家の主', 'カーター', '呪詛', '素晴らしき眺め', 'サイバー地獄: n番部屋 ネット犯罪を暴く', '夜叉 -容赦なき工作戦-', 'セレブファイブ 〜大舞台への道〜', 'アメリカン・ガール', 'パイレーツ: 失われた王家の秘宝', '瀑布', '真・三國無双', 'ライトニング・ムラリ', 'アリサカ', '真実の穴', '白蛇2: 青蛇興起', 'Look for a Star -星を探して-', 'ビューティフル・ライフ -もう二度と離さない-', '独身の行方', 'SDU 飛虎出征', 'ダマカ: テロ独占生中継', 'チートゲーム', 'わたしたちの愛の距離', 'ゼロからのヒーロー', 'Pomegranates and Myrrh', 'この夏の先には', 'つかみ損ねた恋に: ディレクターズカット', '君が最後の初恋', 'キングダム: アシンの物語', 'スカした彼はサイキック', '美に魅せられて', '第8日の夜', '返校 言葉が消えた日', '甘酸っぱい', '野球少女', '角頭−彷徨人', '最後の願い', 'マイルストーン', 'スーパー・ミー', '密航者', 'ただならない物語', 'The Soul: 繋がれる魂', '楽園の夜', 'ギス＆アン', '愛を探して', 'ワーニング その映画を観るな', 'おかしな子', '陰陽師： 二つの世界', '杏林医院', 'こどもなんてお断り！', 'ヤギを追跡せよ', 'サヤン・ディサヤン： 愛しき人よ', '私たちの歌： 新謡が紡いだ時代', '881 歌え！ パパイヤ', 'ホームラン', '悩める青春のススメ', '詩人の恋', '日々は、うたかたに', 'すばらしき大世界', '同級生マイナス', '世宗大王 星を追う者たち', 'ナマステ・ワハラ ~トラブルよ、こんにちは~', '弱くて強い女たち', 'スペース・スウィーパーズ', '陰陽師 とこしえの夢', 'ナタ転生', "Pinkfong & Baby Shark's Space Adventure", 'なんと父よ!', 'トリ
雑な物語', 'アリババと七人のこびと', 'あなたを夢みて', 'あなたかもしれない', 'あなたがボス', 'アップスタート', 'アジズの奇跡', 'Sの嵐', 'PASKAL: マレーシア海軍特殊部隊', 'G.O.R.A. 絨毯は宇宙を救う!?', 'DRIVE/ドライヴ', 'd@bbe: 精霊の呪い', 'd@bbe 5: 精霊の毒', '8月15日 -インド独立記念日-', '61年目の約束', '2ヵ月と2週間の永遠の恋', 'パラサイト 半地下の家族', '感染家族', '完璧な他人', 'ドアロック', ' ...

# %%
output[:2]
# Out:
# [['JUNG_E/ジョンイ',
#   '罪の後',
#   'ミッション・マジュヌ',
#   'アルハラート+',
#   '未来戦記',
#   'マツの木の家族2',
#   '20世紀のキミ',
#   '奇跡の13人: 僕らのタイ洞窟生還記',
#   'ソウル・バイブス',
#   'ダーリンズ',
#   '一家の主',
#   'カーター',
#   '呪詛',
#   '素晴らしき眺め',
#   'サイバー地獄: n番部屋 ネット犯罪を暴く',
#   '夜叉 -容赦なき工作戦-',
#   'セレブファイブ 〜大舞台への道〜',
#   'アメリカン・ガール',
#   'パイレーツ: 失われた王家の秘宝',
#   '瀑布',
#   '真・三國無双',
#   'ライトニング・ムラリ',
#   'アリサカ',
#   '真実の穴',
#   '白蛇2: 青蛇興起',
#   'Look for a Star -星を探して-',
#   'ビューティフル・ライフ -もう二度と離さない-',
#   '独身の行方',
#   'SDU 飛虎出征',
#   'ダマカ: テロ独占生中継',
#   'チートゲーム',
#   'わたしたちの愛の距離',
#   'ゼロからのヒーロー',
#   'Pomegranates and Myrrh',
#   'この夏の先には',
#   'つかみ損ねた恋に: ディレクターズカット',
#   '君が最後の初恋',
#   'キングダム: アシンの物語',
#   'スカした彼はサイキック',
#   '美に魅せられて',
#   '第8日の夜',
#   '返校 言葉が消えた日',
#   '甘酸っぱい',
#   '野球少女',
#   '角頭−彷徨人',
#   '最後の願い',
#   'マイルストーン',
#   'スーパー・ミー',
#   '密航者',
#   'ただならない物語',
#   'The Soul: 繋がれる魂',
#   '楽園の夜',
#   'ギス＆アン',
#   '愛を探して',
#   'ワーニング その映画を観るな',
#   'おかしな子',
#   '陰陽師： 二つの世界',
#   '杏林医院',
#   'こどもなんてお断り！',
#   'ヤギを追跡せよ',
#   'サヤン・ディサヤン： 愛しき人よ',
#   '私たちの歌： 新謡が紡いだ時代',
#   '881 歌え！ パパイヤ',
#   'ホームラン',
#   '悩める青春のススメ',
#   '詩人の恋',
#   '日々は、うたかたに',
#   'すばらしき大世界',
#   '同級生マイナス',
#   '世宗大王 星を追う者たち',
#   'ナマステ・ワハラ ~トラブルよ、こんにちは~',
#   '弱くて強い女たち',
#   'スペース・スウィーパーズ',
#   '陰陽師 とこしえの夢',
#   'ナタ転生',
#   "Pinkfong & Baby Shark's Space Adventure",
#   'なんと父よ!',
#   'トリバンガ 〜踊れ艶やかに〜',
#   'Wish you 〜僕の心の中、君のメロディー(映画)',
#   'デリー・ゲリー',
#   'アジズのジレンマ',
#   '縄の呪い2',
#   'チャ・インピョはどこへ消えたのか?',
#   '薬の神じゃない!',
#   'AKvsAK',
#   '君の心に刻んだ名前',
#   '希望の光',
#   '母の面影が語ること',
#   'ザ・コール',
#   'アルター・ミー: 心に耳を傾けて',
#   'LUDO 〜4つの物語〜',
#   "Girl's Revenge",
#   '漆黒の井戸の底から',
#   '誰も眠らない森',
#   'ニャンてこと!',
#   'ルーナのために',
#   'KCIA 南山の部長たち',
#   'ハクション!',
#   'ギニーとサニーの結婚',
#   'この子をよろしく 〜突然!? 育児トライアル〜'],
#  ['シリアスな男たち',
#   'ドリーとキティ 〜輝け人生!〜',
#   '君にメロメロ',
#   '蘇りへの希望: 生命を未来に託す',
#   'サトリア・ヒーローズ: 暗黒の逆襲',
#   '#生きている',
#   'ハッピー・オールド・イヤー',
#   'ソン・トゥンM-TP: Sky Tour Movie',
#   '呪われの橋',
#   '悪人伝',
#   '最も普通の恋愛',
#   '人間の時間',
#   'SAAHO/サーホー',
#   "クラス '83",
#   '禁断の都市怪談 (韓国版) ',
#   'グルグル・ゴキル 〜はちゃめちゃ教師〜',
#   'グンジャン・サクセナ -夢にはばたいて-',
#   '孤独の夜',
#   'ザ・ラーバ・アイランド・ムービー',
#   '征途 -英雄へのバトルロード-',
#   'スタートアップ!',
#   'あるメイドの秘密',
#   'シークレット・ジョブ',
#   'ブーブル',
#   '息がつまりそう',
#   'スウィング・キッズ',
#   '狩りの時間',
#   'ひとつの太陽',
#   'マスカ 〜夢と幸せの味〜',
#   '添い寝フレンド',
#   'レンタル彼女2',
#   'トッツィーズ&フェイクスター',
#   '恋愛被害者の会2',
#   '恋愛被害者の会',
#   '恋の紫煙',
#   '恋に落ちずにいられない',
#   '流転の地球',
#   '有罪',
#   '勇者は再び巡り会う',
#   '夜の珍客',
#   '毎日あなたを愛してる',
#   '麻薬王',
#   '麻雀ヒーローズ',
#   '僕らの先にある道',
#   '忘れられないあなた',
#   '慕情のアンソロジー',
#   '別れのセットリスト',
#   '平方メートルの恋',
#   '不死身のブリジ・モハン',
#   '必ず捕まえる',
#   '熱砂の記憶 -ラガーン撮影記-',
#   '泥棒はスーパーマン2 絶体絶命!?',
#   '超常現象調査官',
#   '眺望良好',
#   '貯水池ゲーム',
#   '地上の星たち',
#   '脱出(2017年・韓国)',
#   '第九分局',
#   '替え玉美女はトラブルの元',
#   '対決! 広東料理vsフレンチ',
#   '先に愛した人',
#   '尋問(2015年)',
#   '人狼(2018年)',
#   '新郎の条件2: 敗者復活',
#   '新郎の条件',
#   '心惑いて行く先は',
#   '信じる心、危機一髪!',
#   '上流階級',
#   '上海要塞',
#   '呪いのキス -哀しき少女の恋-',
#   '借金取りとマネージャー',
#   '失恋の33日',
#   '私たちの予感',
#   '最強の出前人',
#   '鋼鉄の雨',
#   '紅き大魚の伝説',
#   '広告代理店の掟',
#   '幸福都市',
#   '元カレと解けない恋の疑問',
#   '結婚相談所2: 割礼大作戦',
#   '結婚相談所',
#   '結婚なんて許さない!',
#   '君はクレイジーでビューティフル',
#   '君だけを愛している',
#   '君こそがすべて',
#   '君が気づいていなくても',
#   '恐怖のアンソロジー',
#   '記憶の夜',
#   '危険なUターン',
#   '危ない女たち',
#   '怪奇温泉旅館',
#   '家族のあいだで',
#   '音楽教師 -切ない恋のメロディ-',
#   '運命というもの',
#   '悪魔に呼ばれる前に',
#   '愛しのあの子にメッセージ',
#   'ロマンチック・トラブル2: 結婚秒読み',
#   'ロマンチック・トラブル',
#   'ロスト・イン・ラブ',
#   'レインボー']]

# %%
##データフレームを作成する
df=pd.DataFrame(output)

#中身の確認
df.head()
# Out:
#                            0                1              2   \
# 0                 JUNG_E/ジョンイ              罪の後     ミッション・マジュヌ
# 1                    シリアスな男たち  ドリーとキティ 〜輝け人生!〜         君にメロメロ
# 2                ルシッドドリーム/明晰夢    リベンジャー 無敵の復讐心       リーサル・ゲーム
# 3  工作 黒金星 (ブラック･ヴィーナス) と呼ばれた男           いつか家族に  目撃者(2018年・韓国)
#
#                  3                  4              5              6   \
# 0           アルハラート+               未来戦記       マツの木の家族2        20世紀のキミ
# 1  蘇りへの希望: 生命を未来に託す  サトリア・ヒーローズ: 暗黒の逆襲         #生きている  ハッピー・オールド・イヤー
# 2     ラブ・アフェア めぐり逢い             ラブ O2O  ラジマライス 父の秘密作戦     よみがえったスザンナ
# 3      ときめきプリンセス婚活記           スウィンダラーズ   The Witch/魔女     クレイジー・リッチ!
#
#                            7            8             9   ...            90  \
# 0          奇跡の13人: 僕らのタイ洞窟生還記     ソウル・バイブス         ダーリンズ  ...  LUDO 〜4つの物語〜
# 1  ソン・トゥンM-TP: Sky Tour Movie        呪われの橋           悪人伝  ...        怪奇温泉旅館
# 2                    ヤミ金バスターズ  やっと見つけた本当の恋      もう一度あなたと  ...         ドアロック
# 3             ミッドナイトランナー(韓国版)         犯罪都市  コンフィデンシャル/共助  ...          None
#
#                91                92           93              94  \
# 0  Girl's Revenge         漆黒の井戸の底から      誰も眠らない森         ニャンてこと!
# 1         家族のあいだで  音楽教師 -切ない恋のメロディ-      運命というもの       悪魔に呼ばれる前に
# 2           君の誕生日             幼い依頼人  エクストリーム・ジョブ  EXIT(2018年・韓国)
# 3            None              None         None            None
#
#              95                   96           97                    98  \
# 0       ルーナのために         KCIA 南山の部長たち       ハクション!            ギニーとサニーの結婚
# 1  愛しのあの子にメッセージ  ロマンチック・トラブル2: 結婚秒読み  ロマンチック・トラブル             ロスト・イン・ラブ
# 2  神と共に 第1章:罪と罰         神と共に 第2章:因と縁        コンジアム  ザ・ネゴシエーション(2018年・韓国)
# 3          None                 None         None                  None
#
#                         99
# 0  この子をよろしく 〜突然!? 育児トライアル〜
# 1                    レインボー
# 2                僕たちの復讐ノート
# 3                     None
#
# [4 rows x 100 columns]

# %%
##to_csvを使用してcsv出力する
df.to_csv('NETFLIX_アジア映画.csv' ,encoding = 'utf-8-sig')
